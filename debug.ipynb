# %%
import numpy as np

# %%
from src.utils.main_utils import load_object

train_array = np.load('artifact/03_04_2026_00_35_50/data_transformation/transformed/train.npy')
test_array = np.load('artifact/03_04_2026_00_35_50/data_transformation/transformed/test.npy')

print(f"Train Shape: {train_array.shape}")
print(f"Test Shape: {test_array.shape}")
# Out:
# Train Shape: (2954820, 29)
# Test Shape: (53460, 29)
